# %%
# !pip install langchain_community
# Out:
# Requirement already satisfied: langchain_community in ./env/lib/python3.11/site-packages (0.2.17)
# Requirement already satisfied: PyYAML>=5.3 in ./env/lib/python3.11/site-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./env/lib/python3.11/site-packages (from langchain_community) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./env/lib/python3.11/site-packages (from langchain_community) (3.10.10)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in ./env/lib/python3.11/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: langchain<0.3.0,>=0.2.16 in ./env/lib/python3.11/site-packages (from langchain_community) (0.2.16)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.39 in ./env/lib/python3.11/site-packages (from langchain_community) (0.2.41)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.112 in ./env/lib/python3.11/site-packages (from langchain_community) (0.1.135)
# Requirement already satisfied: numpy<2,>=1 in ./env/lib/python3.11/site-packages (from langchain_community) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in ./env/lib/python3.11/site-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in ./env/lib/python3.11/site-packages (from langchain_community) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in ./env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in ./env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in ./env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.15.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./env/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./env/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in ./env/lib/python3.11/site-packages (from langchain<0.3.0,>=0.2.16->langchain_community) (0.2.4)
# Requirement already satisfied: pydantic<3,>=1 in ./env/lib/python3.11/site-packages (from langchain<0.3.0,>=0.2.16->langchain_community) (2.9.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./env/lib/python3.11/site-packages (from langchain-core<0.3.0,>=0.2.39->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in ./env/lib/python3.11/site-packages (from langchain-core<0.3.0,>=0.2.39->langchain_community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in ./env/lib/python3.11/site-packages (from langchain-core<0.3.0,>=0.2.39->langchain_community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./env/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.112->langchain_community) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./env/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.112->langchain_community) (3.10.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in ./env/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.112->langchain_community) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./env/lib/python3.11/site-packages (from requests<3,>=2->langchain_community) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in ./env/lib/python3.11/site-packages (from requests<3,>=2->langchain_community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./env/lib/python3.11/site-packages (from requests<3,>=2->langchain_community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./env/lib/python3.11/site-packages (from requests<3,>=2->langchain_community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in ./env/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.1.1)
# Requirement already satisfied: anyio in ./env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain_community) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in ./env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain_community) (1.0.6)
# Requirement already satisfied: sniffio in ./env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain_community) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in ./env/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain_community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./env/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.39->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./env/lib/python3.11/site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.16->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in ./env/lib/python3.11/site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.16->langchain_community) (2.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./env/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Requirement already satisfied: propcache>=0.2.0 in ./env/lib/python3.11/site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain_community) (0.2.0)

# %%
from crewai import Agent, Task, Crew

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import os
os.environ["OPENAI_MODEL_NAME"] = 'gpt-3.5-turbo'

# %%
planner = Agent(
    role="Content Planner",
    goal="Plan engaging and factually accurate content on {topic}",
    backstory="""
        You are working on planning a blog article,
        About a topic : {topic}
        You collect the information that helps the audience learn something 
        and make informed decisions. Your work is the basis for the content writer to write an articles
        on this topic
    
     """,
     allow_delegation=False,
     verbose=True
)

# %%
writer = Agent(
    role="Content Writer",
    goal="Write insightful and factually accurate "
         "opinion piece about the topic: {topic}",
    backstory="You're working on a writing "
              "a new opinion piece about the topic: {topic}. "
              "You base your writing on the work of "
              "the Content Planner, who provides an outline "
              "and relevant context about the topic. "
              "You follow the main objectives and "
              "direction of the outline, "
              "as provide by the Content Planner. "
              "You also provide objective and impartial insights "
              "and back them up with information "
              "provide by the Content Planner. "
              "You acknowledge in your opinion piece "
              "when your statements are opinions "
              "as opposed to objective statements.",
    allow_delegation=False,
    verbose=True
)

# %%
editor = Agent(
    role="Editor",
    goal="Edit a given blog post to align with "
         "the writing style of the organization. ",
    backstory="You are an editor who receives a blog post "
              "from the Content Writer. "
              "Your goal is to review the blog post "
              "to ensure that it follows journalistic best practices,"
              "provides balanced viewpoints "
              "when providing opinions or assertions, "
              "and also avoids major controversial topics "
              "or opinions when possible.",
    allow_delegation=False,
    verbose=True
)

# %%
plan = Task(
    description=(
        "1. Prioritize the latest trends, key players, "
            "and noteworthy news on {topic}.\n"
        "2. Identify the target audience, considering "
            "their interests and pain points.\n"
        "3. Develop a detailed content outline including "
            "an introduction, key points, and a call to action.\n"
        "4. Include SEO keywords and relevant data or sources."
    ),
    expected_output="A comprehensive content plan document "
        "with an outline, audience analysis, "
        "SEO keywords, and resources.",
    agent=planner,
)

# %%
write = Task(
    description=(
        "1. Use the content plan to craft a compelling "
            "blog post on {topic}.\n"
        "2. Incorporate SEO keywords naturally.\n"
		"3. Sections/Subtitles are properly named "
            "in an engaging manner.\n"
        "4. Ensure the post is structured with an "
            "engaging introduction, insightful body, "
            "and a summarizing conclusion.\n"
        "5. Proofread for grammatical errors and "
            "alignment with the brand's voice.\n"
    ),
    expected_output="A well-written blog post "
        "in markdown format, ready for publication, "
        "each section should have 2 or 3 paragraphs.",
    agent=writer,
)

# %%
edit = Task(
    description=("Proofread the given blog post for "
                 "grammatical errors and "
                 "alignment with the brand's voice."),
    expected_output="A well-written blog post in markdown format, "
                    "ready for publication, "
                    "each section should have 2 or 3 paragraphs.",
    agent=editor
)

# %%
crew = Crew(
    agents=[planner, writer, editor],
    tasks=[plan, write, edit],    
)

# %%
result = crew.kickoff(inputs={"topic": "Artificial Intelligence"})
# Out:
# # Agent: Content Planner
# ## Task: 1. Prioritize the latest trends, key players, and noteworthy news on Artificial Intelligence.
# 2. Identify the target audience, considering their interests and pain points.
# 3. Develop a detailed content outline including an introduction, key points, and a call to action.
# 4. Include SEO keywords and relevant data or sources.
#
#
# # Agent: Content Planner
# ## Final Answer:
# Title: Understanding Artificial Intelligence: The Latest Trends, Key Players, and How It Impacts You
#
# Introduction:
# In recent years, Artificial Intelligence (AI) has gained significant momentum, revolutionizing industries and transforming the way we live and work. This comprehensive guide will delve into the latest trends, key players in the AI landscape, and how this technology impacts individuals and businesses alike.
#
# Key Points:
# 1. Latest Trends in Artificial Intelligence:
#    a. Machine Learning and Deep Learning advancements.
#    b. Natural Language Processing (NLP) applications.
#    c. AI in healthcare, finance, and other sectors.
#    d. Ethical considerations and regulations in AI development.
#
# 2. Key Players in the AI Industry:
#    a. Tech Giants: Google, Microsoft, Amazon, and IBM leading in AI research and development.
#    b. Startups disrupting traditional industries with innovative AI solutions.
#    c. Academic institutions and research labs contributing to AI breakthroughs.
#
# 3. Impact of AI on Target Audience:
#    a. Businesses: Streamlining operations, enhancing customer experiences, and driving innovation.
#    b. Individuals: Personalized recommendations, convenience in daily tasks, and potential job disruptions.
#    c. Potential benefits and challenges of AI integration for different stakeholders.
#
# 4. Call to Action:
#    a. Stay informed about AI advancements by following reputable AI news sources.
#    b. Explore AI tools and platforms to understand its practical applications.
#    c. Engage in discussions on AI ethics and regulations.
#
# Audience Analysis:
# Target Audience:
# - Business professionals seeking insights on leveraging AI for competitive advantage.
# - Tech enthusiasts interested in the latest developments in artificial intelligence.
# - Individuals curious about how AI impacts their daily lives and future opportunities.
# - Policy makers and regulators concerned about ethical AI implementation.
#
# SEO Keywords:
# 1. Artificial Intelligence trends
# 2. Leading AI companies
# 3. Impact of AI on businesses
# 4. Ethical AI development
# 5. AI applications in daily life
#
# Resources:
# 1. Forbes AI articles
# 2. MIT Technology Review on AI advancements
# 3. Gartner reports on AI market trends
# 4. AI ethics guidelines by organizations like IEEE and ACM
# 5. AI industry updates from TechCrunch and VentureBeat
#
# By addressing the latest trends, key players, audience interests, and SEO optimization, this content plan aims to inform and engage readers on the dynamic world of Artificial Intelligence.
#
#
# # Agent: Content Writer
# ## Task: 1. Use the content plan to craft a compelling blog post on Artificial Intelligence.
# 2. Incorporate SEO keywords naturally.
# 3. Sections/Subtitles are properly named in an engaging manner.
# 4. Ensure the post is structured with an engaging introduction, insightful body, and a summarizing conclusion.
# 5. Proofread for grammatical errors and alignment with the brand's voice.
#
#
#
# # Agent: Content Writer
# ## Final Answer:
# # Understanding Artificial Intelligence: The Latest Trends, Key Players, and How It Impacts You
#
# ## Introduction:
# Artificial Intelligence (AI) has rapidly become a focal point of innovation, disrupting various sectors and influencing daily life in profound ways. This blog will provide an insightful exploration of the current trends in AI, highlight the key players shaping the industry, and examine the far-reaching implications of AI on both businesses and individuals.
#
# ## Latest Trends in Artificial Intelligence:
# Artificial Intelligence is witnessing unprecedented growth, with Machine Learning and Deep Learning at the forefront of advancements. These technologies are powering breakthroughs in automation, predictive analytics, and cognitive computing. Moreover, Natural Language Processing (NLP) applications are revolutionizing how machines interact with human language, enabling advancements in chatbots, translation tools, and sentiment analysis. In sectors like healthcare and finance, AI is driving innovations such as personalized medicine, fraud detection, and algorithmic trading. However, as AI continues to evolve, ethical considerations regarding privacy, bias, and transparency in AI algorithms have sparked discussions on regulations and responsible development practices.
#
# ## Key Players in the AI Industry:
# Tech Giants like Google, Microsoft, Amazon, and IBM are leading the charge in AI research and development, leveraging their vast resources to drive innovation across various domains. Simultaneously, startups are disrupting traditional industries with agile and specialized AI solutions, challenging established players with niche applications and agile development cycles. Academic institutions and research labs also play a crucial role in advancing AI capabilities, contributing to breakthroughs in areas like reinforcement learning, neural networks, and explainable AI, thereby enriching the broader AI ecosystem with cutting-edge research and talent.
#
# ## Impact of AI on Target Audience:
# For businesses, the integration of AI offers unparalleled opportunities to streamline operations, enhance customer experiences, and foster a culture of innovation. From optimizing supply chains to predicting consumer behavior, AI empowers organizations to make data-driven decisions and stay ahead in competitive markets. On the individual front, AI transforms daily experiences through personalized recommendations, intelligent assistants, and smart devices that simplify tasks and enrich daily living. Nevertheless, the rise of AI raises concerns about potential job disruptions and the need for upskilling to adapt to an automated future, highlighting the importance of preparing for the evolving job market and embracing lifelong learning opportunities.
#
# ## Call to Action:
# To stay abreast of AI trends and developments, follow reputable AI news sources like Forbes, MIT Technology Review, and Gartner reports. Furthermore, explore AI tools and platforms to gain hands-on experience with AI applications and understand its practical implications. Engaging in discussions surrounding AI ethics and regulations is imperative for fostering a responsible AI ecosystem that prioritizes transparency, accountability, and societal well-being.
#
# ## Conclusion:
# Artificial Intelligence continues to reshape industries, redefine human-machine interactions, and raise pertinent questions about the future of work and society. By navigating the evolving landscape of AI trends, understanding the pivotal roles of key industry players, and embracing the transformative impact of AI on businesses and individuals, we can embark on a journey of informed exploration and strategic adaptation to the AI-driven world.
#
# Remember, the dynamic realm of AI offers myriad opportunities for growth and innovation, and staying informed and proactive in understanding its nuances will be essential in navigating the exciting possibilities and challenges that lie ahead. Embrace the AI revolution with curiosity, critical thinking, and a commitment to shaping a future where AI enhances human capabilities and enriches the fabric of society.
#
#
# # Agent: Editor
# ## Task: Proofread the given blog post for grammatical errors and alignment with the brand's voice.
#
#
# # Agent: Editor
# ## Final Answer:
# # Understanding Artificial Intelligence: The Latest Trends, Key Players, and How It Impacts You
#
# ## Introduction:
# Artificial Intelligence (AI) has rapidly become a focal point of innovation, disrupting various sectors and influencing daily life in profound ways. This blog provides an insightful exploration of the current trends in AI, highlights the key players shaping the industry, and examines the far-reaching implications of AI on both businesses and individuals.
#
# ## Latest Trends in Artificial Intelligence:
# Artificial Intelligence is witnessing unprecedented growth, with Machine Learning and Deep Learning spearheading advancements. These technologies are driving breakthroughs in automation, predictive analytics, and cognitive computing. Moreover, Natural Language Processing (NLP) applications are transforming how machines interact with human language, enabling progress in chatbots, translation tools, and sentiment analysis. In sectors like healthcare and finance, AI fosters innovations such as personalized medicine, fraud detection, and algorithmic trading. However, as AI progresses, ethical considerations regarding privacy, bias, and transparency in AI algorithms have triggered discussions on regulations and responsible development practices.
#
# ## Key Players in the AI Industry:
# Tech Giants like Google, Microsoft, Amazon, and IBM lead AI research and development, using their vast resources to innovate across various domains. Concurrently, startups are disrupting traditional industries with agile and specialized AI solutions, challenging established players with niche applications and agile development cycles. Academic institutions and research labs also play a critical role in advancing AI capabilities, contributing to breakthroughs in areas like reinforcement learning, neural networks, and explainable AI, thereby enriching the broader AI ecosystem with cutting-edge research and talent.
#
# ## Impact of AI on Target Audience:
# For businesses, AI integration offers unparalleled opportunities to streamline operations, enhance customer experiences, and foster innovation. From optimizing supply chains to predicting consumer behavior, AI empowers organizations to make data-driven decisions and stay competitive. On an individual level, AI transforms daily experiences through personalized recommendations, intelligent assistants, and smart devices that simplify tasks and enrich daily living. Nevertheless, the rise of AI raises concerns about potential job disruptions and the need for upskilling to adapt to an automated future, emphasizing the importance of preparing for the evolving job market and embracing lifelong learning opportunities.
#
# ## Call to Action:
# To stay updated on AI trends and developments, follow reputable AI news sources like Forbes, MIT Technology Review, and Gartner reports. Furthermore, explore AI tools and platforms to gain hands-on experience with AI applications and understand its practical implications. Engaging in discussions about AI ethics and regulations is crucial for fostering a responsible AI ecosystem that prioritizes transparency, accountability, and societal well-being.
#
# ## Conclusion:
# Artificial Intelligence continues to reshape industries, redefine human-machine interactions, and raise questions about the future of work and society. By navigating AI trends, understanding key industry players, and embracing the transformative impact of AI on businesses and individuals, we can embark on a journey of informed exploration and strategic adaptation to the AI-driven world.
#
# Remember, the dynamic realm of AI presents numerous opportunities for growth and innovation, and staying informed and proactive in understanding its nuances will be crucial in navigating the possibilities and challenges ahead. Embrace the AI revolution with curiosity, critical thinking, and a commitment to shaping a future where AI enhances human capabilities and enriches society.
